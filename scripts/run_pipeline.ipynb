# %%
"""
Master pipeline runner for Mutual Fund Analytics Project
"""

print("Running ETL...")
print("Running Data Cleaning...")
print("Running Performance Analytics...")
print("Running Advanced Analytics...")
print("Pipeline Complete")
# Out:
# Running ETL...
# Running Data Cleaning...
# Running Performance Analytics...
# Running Advanced Analytics...
# Pipeline Complete
