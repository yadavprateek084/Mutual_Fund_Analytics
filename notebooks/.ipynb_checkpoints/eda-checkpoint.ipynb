# %%
import pandas as pd
import sqlite3
import matplotlib.pyplot as plt
import seaborn as sns

# Make charts larger
plt.rcParams["figure.figsize"] = (10, 6)

# Connect to database
conn = sqlite3.connect("database/mutual_fund.db")

print("Connected Successfully")
# Out:
# Running cells with '.venv (Python 3.13.7)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"c:/Users/yadav/Downloads/Capstone Project I - Mutual Fund Analytics/.venv/Scripts/python.exe" -m pip install ipykernel -U --force-reinstall'
